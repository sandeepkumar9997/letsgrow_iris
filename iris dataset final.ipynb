# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [raw]
# Column 0: sepal_length - The measurement of sepal length in centimeters.
# Column 1: sepal_width - The measurement of sepal width in centimeters.
# Column 2: petal_length - The measurement of petal length in centimeters.
# Column 3: petal_width - The measurement of petal width in centimeters.
# Column 4: species - The species of the Iris flower. It is stored as an object (string) data type.
# 'setosa': This refers to the Iris setosa species.
# 'versicolor': This refers to the Iris versicolor species.
# 'virginica': This refers to the Iris virginica species.
# The dataset consists of 150 samples, and all columns have 150 non-null values, indicating that there are no missing values in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species'].describe()
# Out:
# count        150
# unique         3
# top       setosa
# freq          50
# Name: species, dtype: object

# %%
df_cat = df.select_dtypes(include='object')
df_cat
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
df_num = df.select_dtypes(exclude='object')
df_num
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
for i in df.columns:
    print('------------------------------------',i,'------------------------------------')
    print(df[i].unique())
# Out:
# ------------------------------------ sepal_length ------------------------------------
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
# ------------------------------------ sepal_width ------------------------------------
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
# ------------------------------------ petal_length ------------------------------------
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
# ------------------------------------ petal_width ------------------------------------
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
# ------------------------------------ species ------------------------------------
# ['setosa' 'versicolor' 'virginica']

# %%
# Calculate descriptive statistics for sepal length
sepal_length_stats = df['sepal_length'].describe()
print(sepal_length_stats)
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# # ANALYSIS

# %%
import matplotlib.pyplot as plt

# Create a histogram for sepal width
plt.hist(df['sepal_width'], bins=10)
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width')
plt.show()

# %%
import seaborn as sns

# Create a KDE plot for petal length
sns.kdeplot(df['petal_length'])
plt.xlabel('Petal Length')
plt.ylabel('Density')
plt.title('KDE Plot of Petal Length')
plt.show()

# %%
import seaborn as sns

# Create a box plot for petal width
sns.boxplot(df['petal_width'])
plt.xlabel('Petal Width')
plt.title('Box Plot of Petal Width')
plt.show()

# %%
# Histogram
df.hist()
plt.show()

# Box plots
df.plot(kind='box')
plt.show()

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create box plots for each feature by species
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
sns.boxplot(x='species', y='sepal_length', data=df)
plt.subplot(2, 2, 2)
sns.boxplot(x='species', y='sepal_width', data=df)
plt.subplot(2, 2, 3)
sns.boxplot(x='species', y='petal_length', data=df)
plt.subplot(2, 2, 4)
sns.boxplot(x='species', y='petal_width', data=df)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # STASTICAL ANALYSIS

# %%
# 1

# %% [raw]
# # Null Hypothesis (H0): There is no correlation between sepal length and petal length in the population.
# # Alternative Hypothesis (H1): There is a correlation between sepal length and petal length in the population.

# %%
from scipy.stats import stats
x = df['sepal_length']
y = df['petal_length']

# Perform Pearson correlation coefficient calculation
correlation, p_value = stats.pearsonr(x, y)

# Print the correlation coefficient and p-value
print("Correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Correlation coefficient: 0.8717537758865831
# p-value: 1.0386674194498099e-47

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Conclusion:
# Based on the calculated correlation coefficient of 0.872 and the very low p-value, we have strong evidence to support the alternative hypothesis. Therefore, we can conclude that there is a significant positive correlation between sepal length and petal length in the Iris dataset.

# %%
# 2

# %% [raw]
# Null hypothesis (H0): There is no correlation between sepal length and sepal width in the population.
# Alternative hypothesis (H1): There is a correlation between sepal length and sepal width in the population.

# %%
x = df['sepal_length']
y = df['sepal_width']

# Perform Pearson correlation coefficient calculation
correlation, p_value = stats.pearsonr(x, y)

# Print the correlation coefficient and p-value
print("Correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Correlation coefficient: -0.11756978413300187
# p-value: 0.15189826071144835

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# fails to reject null hypothesis

# %% [raw]
# Since the p-value is greater than 0.05, we fail to reject the null hypothesis. Therefore, we do not have sufficient evidence to conclude that there is a significant correlation between sepal length and sepal width in the population represented by the Iris dataset.

# %%
# 3

# %% [raw]
# Null hypothesis (H0): There is no correlation between sepal length and petal width in the population.
# Alternative hypothesis (H1): There is a correlation between sepal length and petal width in the population.

# %%
x = df['sepal_length']
y = df['petal_width']

# Perform Pearson correlation coefficient calculation
correlation, p_value = stats.pearsonr(x, y)

# Print the correlation coefficient and p-value
print("Correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Correlation coefficient: 0.8179411262715752
# p-value: 2.3254980797935457e-37

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small, we reject the null hypothesis in favor of the alternative hypothesis. Therefore, we have sufficient evidence to conclude that there is a significant positive correlation between sepal length and petal width in the population represented by the Iris dataset.

# %%
# 4

# %% [raw]
# Null hypothesis (H0): There is no correlation between petal width and petal length in the population.
# Alternative hypothesis (H1): There is a correlation between petal width and petal length in the population.

# %%
x = df['petal_width']
y = df['petal_length']

# Perform Pearson correlation coefficient calculation
correlation, p_value = stats.pearsonr(x, y)

# Print the correlation coefficient and p-value
print("Correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Correlation coefficient: 0.9628654314027965
# p-value: 4.675003907324524e-86

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small, we reject the null hypothesis in favor of the alternative hypothesis. Therefore, we have sufficient evidence to conclude that there is a significant positive correlation between petal width and petal length in the population represented by the Iris dataset.

# %%
# 5

# %% [raw]
# Null hypothesis (H0): There is no correlation between petal width and petal length in the population.
# Alternative hypothesis (H1): There is a correlation between petal width and petal length in the population.

# %%
x = df['petal_width']
y = df['sepal_width']

# Perform Pearson correlation coefficient calculation
correlation, p_value = stats.pearsonr(x, y)

# Print the correlation coefficient and p-value
print("Correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Correlation coefficient: -0.3661259325364387
# p-value: 4.073228513246304e-06

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small, we reject the null hypothesis in favor of the alternative hypothesis. Therefore, we have sufficient evidence to conclude that there is a significant positive correlation between petal width and petal length in the population represented by the Iris dataset.

# %%
# 6

# %% [raw]
# Null hypothesis (H0): There is no significant difference in the means of sepal length among the different species.
# Alternative hypothesis (H1): There is a significant difference in the means of sepal length among the different species.

# %%
# Perform ANOVA for sepal_length
anova_result_sl = stats.f_oneway(df[df['species'] == 'setosa']['sepal_length'],
                           df[df['species'] == 'versicolor']['sepal_length'],
                           df[df['species'] == 'virginica']['sepal_length'])
f_value =  anova_result_sl.statistic
p_value = anova_result_sl.pvalue
print("ANOVA for Sepal Length:")
print("F-value:", anova_result_sl.statistic)
print("p-value:", anova_result_sl.pvalue)
# Out:
# ANOVA for Sepal Length:
# F-value: 119.26450218450468
# p-value: 1.6696691907693826e-31

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is significantly smaller than the significance level of 0.05, we reject the null hypothesis in favor of the alternative hypothesis. Therefore, we have sufficient evidence to conclude that there is a significant difference in the means of sepal length among the different species of Iris flowers.

# %%
# 7

# %% [raw]
# Null hypothesis (H0): There is no significant difference in the means of petal length among the different species.
# Alternative hypothesis (H1): There is a significant difference in the means of petal length among the different species.

# %%
# Perform ANOVA for petal_length
anova_result_sl = stats.f_oneway(df[df['species'] == 'setosa']['petal_length'],
                           df[df['species'] == 'versicolor']['petal_length'],
                           df[df['species'] == 'virginica']['petal_length'])
f_value =  anova_result_sl.statistic
p_value = anova_result_sl.pvalue
print("ANOVA for Sepal Length:")
print("F-value:", anova_result_sl.statistic)
print("p-value:", anova_result_sl.pvalue)

# Repeat the above steps for other numerical columns (sepal_width, petal_length, petal_width)
# Out:
# ANOVA for Sepal Length:
# F-value: 1180.161182252981
# p-value: 2.8567766109615584e-91

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small (close to 0), we reject the null hypothesis in favor of the alternative hypothesis. Thus, there is strong evidence to suggest that there is a significant difference in the means of petal length among the different species of Iris flowers.

# %%
# 8

# %% [raw]
# Null hypothesis (H0): There is no significant difference in the means of petal width among the different species.
# Alternative hypothesis (H1): There is a significant difference in the means of petal width among the different species.

# %%
# Perform ANOVA for petal_width
anova_result_sl = stats.f_oneway(df[df['species'] == 'setosa']['petal_width'],
                           df[df['species'] == 'versicolor']['petal_width'],
                           df[df['species'] == 'virginica']['petal_width'])
f_value =  anova_result_sl.statistic
p_value = anova_result_sl.pvalue
print("ANOVA for Sepal Length:")
print("F-value:", anova_result_sl.statistic)
print("p-value:", anova_result_sl.pvalue)

# Repeat the above steps for other numerical columns (sepal_width, petal_length, petal_width)
# Out:
# ANOVA for Sepal Length:
# F-value: 960.007146801809
# p-value: 4.169445839443116e-85

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small (close to 0), we reject the null hypothesis in favor of the alternative hypothesis. Thus, there is strong evidence to suggest that there is a significant difference in the means of petal width among the different species of Iris flowers.

# %%
# 9

# %% [raw]
# Null hypothesis (H0): There is no significant difference in the means of sepal width among the different species.
# Alternative hypothesis (H1): There is a significant difference in the means of sepal width among the different species.

# %%
# Perform ANOVA for sepal_width
anova_result_sl = stats.f_oneway(df[df['species'] == 'setosa']['sepal_width'],
                           df[df['species'] == 'versicolor']['sepal_width'],
                           df[df['species'] == 'virginica']['sepal_width'])
f_value =  anova_result_sl.statistic
p_value = anova_result_sl.pvalue
print("ANOVA for Sepal Length:")
print("F-value:", anova_result_sl.statistic)
print("p-value:", anova_result_sl.pvalue)

# Repeat the above steps for other numerical columns (sepal_width, petal_length, petal_width)
# Out:
# ANOVA for Sepal Length:
# F-value: 49.160040089612075
# p-value: 4.492017133309115e-17

# %%
if p_value <0.05:
    print('reject the null hypothesis')
elif p_value > 0.05:
    print('fails to reject null hypothesis')
# Out:
# reject the null hypothesis

# %% [raw]
# Since the p-value is extremely small (close to 0), we reject the null hypothesis in favor of the alternative hypothesis. Thus, there is strong evidence to suggest that there is a significant difference in the means of sepal width among the different species of Iris flowers.

# %% [raw]
# Based on the analysis conducted on the Iris dataset, we can draw the following conclusions:
#
# 1. Correlation Analysis:
#    - Sepal Length and Petal Length: There is a strong positive correlation between sepal length and petal length, with a correlation coefficient of 0.87. The p-value is very low, indicating that the correlation is statistically significant.
#    - Sepal Length and Sepal Width: There is a weak negative correlation between sepal length and sepal width, with a correlation coefficient of -0.12. The p-value is relatively high (0.15), suggesting that the correlation is not statistically significant.
#    - Sepal Length and Petal Width: There is a strong positive correlation between sepal length and petal width, with a correlation coefficient of 0.82. The p-value is extremely low, indicating a statistically significant correlation.
#    - Petal Width and Petal Length: There is a strong positive correlation between petal width and petal length, with a correlation coefficient of 0.96. The p-value is very low, suggesting a highly significant correlation.
#    - Petal Width and Sepal Width: There is a moderate negative correlation between petal width and sepal width, with a correlation coefficient of -0.37. The p-value is low, indicating a statistically significant correlation.
#
# 2. ANOVA Analysis:
#    - Sepal Length: The ANOVA test indicates a highly significant difference in sepal length among the three species (setosa, versicolor, virginica), with an F-value of 119.26 and an extremely low p-value.
#    - Petal Length: The ANOVA test shows a highly significant difference in petal length among the three species, with an F-value of 1180.16 and an extremely low p-value.
#    - Petal Width: The ANOVA test reveals a highly significant difference in petal width among the three species, with an F-value of 960.01 and an extremely low p-value.
#    - Sepal Width: The ANOVA test demonstrates a significant difference in sepal width among the three species, with an F-value of 49.16 and a low p-value.
#
# 3. Conclusion:
#    - The Iris dataset exhibits significant correlations between various attributes, particularly petal length and petal width, as well as sepal length and petal length.
#    - The ANOVA analysis reveals that all four attributes (sepal length, sepal width, petal length, and petal width) exhibit significant differences among the three species of Iris flowers (setosa, versicolor, virginica).
#    - These findings suggest that the attributes measured in the Iris dataset can be useful in distinguishing between different species of Iris flowers.
#
# Please note that these conclusions are specific to the Iris dataset and the analysis conducted.

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode the 'species' column
df['species'] = label_encoder.fit_transform(df['species'])

# Print the updated dataset with the new encoded column
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# # MODEL BULIDING

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test - 30
X = df.drop(columns=['species'])
Y = df['species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)
# logistic regression 
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# model training
model.fit(x_train, y_train)
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %%
# knn - k-nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  97.77777777777777

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train, y_train)
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %% [raw]
# Here are the accuracy scores for different classification models applied to the Iris dataset:
#
# 1. Logistic Regression: Accuracy = 97.78%
# 2. K-Nearest Neighbors (KNN): Accuracy = 97.78%
# 3. Decision Tree: Accuracy = 95.56%
# 4. Random Forest: Accuracy = 97.78%
#
# These accuracy scores indicate the performance of each model in predicting the species of Iris flowers based on the given attributes. It appears that logistic regression, KNN, and random forest achieve similar high accuracies, while the decision tree model has a slightly lower accuracy.
#
# Please note that these accuracy scores may vary slightly due to the random nature of the train-test split. Additionally, it's always a good practice to evaluate the models using cross-validation and consider other evaluation metrics to get a comprehensive understanding of their performance.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Create the logistic regression model
model = LogisticRegression()

# Perform cross-validation with 5 folds
scores = cross_val_score(model, X, Y, cv=5)

# Print the accuracy scores for each fold
print("Cross-validation scores:", scores)

# Print the mean accuracy and standard deviation
print("Mean accuracy:", scores.mean())
print("Standard deviation:", scores.std())
# Out:
# Cross-validation scores: [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Mean accuracy: 0.9733333333333334
# Standard deviation: 0.02494438257849294

# %% [raw]
# The cross-validation results indicate the accuracy scores obtained for each fold and the mean accuracy along with the standard deviation. Here's the breakdown of the output:
#
# Cross-validation scores: [0.96666667 1.         0.93333333 0.96666667 1.        ]
# - These are the accuracy scores obtained for each fold of cross-validation. Each score represents the accuracy of the model on a particular fold.
#
# Mean accuracy: 0.9733333333333334
# - This is the mean accuracy calculated by averaging the accuracy scores of all the folds. It provides an estimate of the model's performance across different subsets of the data.
#
# Standard deviation: 0.02494438257849294
# - The standard deviation measures the variability or spread of the accuracy scores. A lower value indicates less variability and more consistency in the model's performance.
#
# Based on the cross-validation results, the logistic regression model achieved a high mean accuracy of approximately 97.33% with a standard deviation of 0.0249. This suggests that the model performs well on the Iris dataset and demonstrates good generalization capabilities.
